# %% [markdown]
# ### Exercise1

# %% [markdown]
# Give the function below, draw the two figures as shown below

# %%
import numpy as np

x = np.linspace(0, 5, 10)
y = x ** 2

# %% [markdown]
# ![ex01_01.png](attachment:ex01_01.png)

# %%
# Your code here for figure 1

# %% [markdown]
# ![ex01_02.png](attachment:ex01_02.png)

# %%
# Your code here for figure 2

# %% [markdown]
# ### Exercise 2
#
# Create a figure that looks like the following

# %% [markdown]
# ![ex02_01.png](attachment:ex02_01.png)

# %%
#your code here

# %% [markdown]
# ### Exercise 3
#
# Create a figure that looks like the following, you may use fill_between function if necessary:

# %% [markdown]
# ![ex03_01.png](attachment:ex03_01.png)

# %%
n = np.array([0,1,2,3,4,5])
xx = np.linspace(-0.75, 1., 100)

#you code here

# %% [markdown]
# ### Exercise4
# Create a chart as shown below. Pay attention to the legends, axes and title, etc.

# %% [markdown]
# ![ex04_01.png](attachment:ex04_01.png)

# %%
# bar example
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.75       # the width of the bars: can also be len(x) sequence

#you code below
#hint: use plt.bar to create the chart

# %% [markdown]
# ### Exercise 5
# Given the precipitation for a city X, please create a chart that looks nice to you and can convey as much information as possible.
#
# 1) Please try at least three type of charts, including line, bar, scatter, etc.
#
# 2) You chart should have proper legends, axes names, ticks(use month name as X axis).

# %%
# create variables for each month of average precipitation for City X
jan = 0.70 * 25.4
feb = 0.75 * 25.4
mar = 1.85 * 25.4
apr = 2.93 * 25.4
may = 3.05 * 25.4
june = 2.02 * 25.4
july = 1.93 * 25.4
aug = 1.62 * 25.4
sept = 1.84 * 25.4
oct = 1.31 * 25.4
nov = 1.39 * 25.4
dec = 0.84 * 25.4

# you code here

# %%
# furthur improvement

# %%
# use the bar chart, etc
